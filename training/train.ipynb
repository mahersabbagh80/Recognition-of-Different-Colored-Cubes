# %% [markdown]
# # YOLOv5 Cube Detection Training (Colab)
#
# Placeholder notebook for **Milestone 3**.
#
# ## Steps (to implement)
#
# 1. Upload Roboflow dataset (YOLOv5 format)
# 2. Clone YOLOv5 (Ultralytics)
# 3. Train YOLOv5s — 50–100 epochs, classes: `red_cube`, `green_cube`, `blue_cube`
# 4. Validate on hold-out set
# 5. Export `best.pt` → `best.onnx`
#
# **Dataset:** https://universe.roboflow.com/jakub-slof/red-green-blue-cube-detection/dataset/1
